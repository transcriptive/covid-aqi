# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### State History

# %%
states_history = pd.read_csv('./datasets/Covid-19-Data/all-states-history.csv', index_col=0)

# %%
states_history.head()
# Out:
#            state    death  deathConfirmed  deathIncrease  deathProbable  \
# date
# 2021-03-07    AK    305.0             NaN              0            NaN
# 2021-03-07    AL  10148.0          7963.0             -1         2185.0
# 2021-03-07    AR   5319.0          4308.0             22         1011.0
# 2021-03-07    AS      0.0             NaN              0            NaN
# 2021-03-07    AZ  16328.0         14403.0              5         1925.0
#
#             hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# date
# 2021-03-07        1293.0                  1293.0                   33.0
# 2021-03-07       45976.0                 45976.0                  494.0
# 2021-03-07       14926.0                 14926.0                  335.0
# 2021-03-07           NaN                     NaN                    NaN
# 2021-03-07       57907.0                 57907.0                  963.0
#
#             hospitalizedIncrease  inIcuCumulative  ...  totalTestResults  \
# ...

# %%
states_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20780 entries, 2021-03-07 to 2020-01-13
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state                             20780 non-null  object
#  1   death                             19930 non-null  float64
#  2   deathConfirmed                    9469 non-null   float64
#  3   deathIncrease                     20780 non-null  int64
#  4   deathProbable                     7593 non-null   float64
#  5   hospitalized                      12382 non-null  float64
#  6   hospitalizedCumulative            12382 non-null  float64
#  7   hospitalizedCurrently             17339 non-null  float64
#  8   hospitalizedIncrease              20780 non-null  int64
#  9   inIcuCumulative                   3789 non-null   float64
#  10  inIcuCurrently                    11636 non-null  float64
# ...

# %%
states_history.isna().sum()
# Out:
# state                                   0
# death                                 850
# deathConfirmed                      11311
# deathIncrease                           0
# deathProbable                       13187
# hospitalized                         8398
# hospitalizedCumulative               8398
# hospitalizedCurrently                3441
# hospitalizedIncrease                    0
# inIcuCumulative                     16991
# inIcuCurrently                       9144
# negative                             7490
# negativeIncrease                        0
# negativeTestsAntibody               19322
# negativeTestsPeopleAntibody         19808
# negativeTestsViral                  15756
# onVentilatorCumulative              19490
# onVentilatorCurrently               11654
# positive                              188
# positiveCasesViral                   6534
# positiveIncrease                        0
# positiveScore                           0
# ...

# %% [markdown]
# ---
# ### LA Times dataset

# %%
cali_counties = pd.read_csv('./datasets/Covid-19-Data/latimes-county-totals.csv', index_col=0)
cali_counties
# Out:
#                 county  fips  confirmed_cases  deaths  new_confirmed_cases  \
# date
# 2021-05-13     Alameda     1            87940    1657                 27.0
# 2021-05-13      Alpine     3               88       0                  0.0
# 2021-05-13      Amador     5             3623      47                  0.0
# 2021-05-13       Butte     7            11843     182                 26.0
# 2021-05-13   Calaveras     9             2130      54                  1.0
# ...                ...   ...              ...     ...                  ...
# 2020-01-26      Solano    95                0       0                  NaN
# 2020-01-26      Sonoma    97                0       0                  NaN
# 2020-01-26  Stanislaus    99                0       0                  NaN
# 2020-01-26     Ventura   111                0       0                  NaN
# 2020-01-26        Yolo   113                0       0                  NaN
#
#             new_deaths
# date
# 2021-05-13         0.0
# ...

# %%
cali_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24856 entries, 2021-05-13 to 2020-01-26
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county               24856 non-null  object
#  1   fips                 24856 non-null  int64
#  2   confirmed_cases      24856 non-null  int64
#  3   deaths               24856 non-null  int64
#  4   new_confirmed_cases  24798 non-null  float64
#  5   new_deaths           24798 non-null  float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.3+ MB

# %%
cali_counties.isna().sum()
# Out:
# county                  0
# fips                    0
# confirmed_cases         0
# deaths                  0
# new_confirmed_cases    58
# new_deaths             58
# dtype: int64

# %%
# get LA county
la_county = cali_counties.loc[cali_counties.county == 'Los Angeles']
la_county
# Out:
#                  county  fips  confirmed_cases  deaths  new_confirmed_cases  \
# date
# 2021-05-13  Los Angeles    37          1236469   24057                213.0
# 2021-05-12  Los Angeles    37          1236256   24041                257.0
# 2021-05-11  Los Angeles    37          1235999   24021                171.0
# 2021-05-10  Los Angeles    37          1235828   24003                177.0
# 2021-05-09  Los Angeles    37          1235651   23999                229.0
# ...                 ...   ...              ...     ...                  ...
# 2020-01-30  Los Angeles    37                1       0                  0.0
# 2020-01-29  Los Angeles    37                1       0                  0.0
# 2020-01-28  Los Angeles    37                1       0                  0.0
# 2020-01-27  Los Angeles    37                1       0                  0.0
# 2020-01-26  Los Angeles    37                1       0                  NaN
#
#             new_deaths
# date
# ...

# %%
la_county_2020 = la_county.drop(la_county.index[0:133])
la_county_2020
# Out:
#                  county  fips  confirmed_cases  deaths  new_confirmed_cases  \
# date
# 2020-12-31  Los Angeles    37           771519   10359              14679.0
# 2020-12-30  Los Angeles    37           756840   10068              10174.0
# 2020-12-29  Los Angeles    37           746666    9806              11806.0
# 2020-12-28  Los Angeles    37           734860    9564              14900.0
# 2020-12-27  Los Angeles    37           719960    9485              12497.0
# ...                 ...   ...              ...     ...                  ...
# 2020-01-30  Los Angeles    37                1       0                  0.0
# 2020-01-29  Los Angeles    37                1       0                  0.0
# 2020-01-28  Los Angeles    37                1       0                  0.0
# 2020-01-27  Los Angeles    37                1       0                  0.0
# 2020-01-26  Los Angeles    37                1       0                  NaN
#
#             new_deaths
# date
# ...

# %%
la_county_2020.to_csv('./datasets/Covid-19-Data/LA_county_covid_2020.csv')
