# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### State History

# %%
states_history = pd.read_csv('./datasets/Covid-19-Data/all-states-history.csv', index_col=0)

# %%
states_history.head()
# Out:
#            state    death  deathConfirmed  deathIncrease  deathProbable  \
# date
# 2021-03-07    AK    305.0             NaN              0            NaN
# 2021-03-07    AL  10148.0          7963.0             -1         2185.0
# 2021-03-07    AR   5319.0          4308.0             22         1011.0
# 2021-03-07    AS      0.0             NaN              0            NaN
# 2021-03-07    AZ  16328.0         14403.0              5         1925.0
#
#             hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# date
# 2021-03-07        1293.0                  1293.0                   33.0
# 2021-03-07       45976.0                 45976.0                  494.0
# 2021-03-07       14926.0                 14926.0                  335.0
# 2021-03-07           NaN                     NaN                    NaN
# 2021-03-07       57907.0                 57907.0                  963.0
#
#             hospitalizedIncrease  inIcuCumulative  ...  totalTestResults  \
# ...

# %%
states_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20780 entries, 2021-03-07 to 2020-01-13
# Data columns (total 40 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state                             20780 non-null  object
#  1   death                             19930 non-null  float64
#  2   deathConfirmed                    9469 non-null   float64
#  3   deathIncrease                     20780 non-null  int64
#  4   deathProbable                     7593 non-null   float64
#  5   hospitalized                      12382 non-null  float64
#  6   hospitalizedCumulative            12382 non-null  float64
#  7   hospitalizedCurrently             17339 non-null  float64
#  8   hospitalizedIncrease              20780 non-null  int64
#  9   inIcuCumulative                   3789 non-null   float64
#  10  inIcuCurrently                    11636 non-null  float64
# ...

# %%
states_history.isna().sum()
# Out:
# state                                   0
# death                                 850
# deathConfirmed                      11311
# deathIncrease                           0
# deathProbable                       13187
# hospitalized                         8398
# hospitalizedCumulative               8398
# hospitalizedCurrently                3441
# hospitalizedIncrease                    0
# inIcuCumulative                     16991
# inIcuCurrently                       9144
# negative                             7490
# negativeIncrease                        0
# negativeTestsAntibody               19322
# negativeTestsPeopleAntibody         19808
# negativeTestsViral                  15756
# onVentilatorCumulative              19490
# onVentilatorCurrently               11654
# positive                              188
# positiveCasesViral                   6534
# positiveIncrease                        0
# positiveScore                           0
# ...

# %% [markdown]
# ---
# ### LA data

# %%
cali_counties = pd.read_csv('./datasets/Covid-19-Data/latimes-county-totals.csv')
cali_counties
# Out:
#              date      county  fips  confirmed_cases  deaths  \
# 0      2021-05-13     Alameda     1            87940    1657
# 1      2021-05-13      Alpine     3               88       0
# 2      2021-05-13      Amador     5             3623      47
# 3      2021-05-13       Butte     7            11843     182
# 4      2021-05-13   Calaveras     9             2130      54
# ...           ...         ...   ...              ...     ...
# 24851  2020-01-26      Solano    95                0       0
# 24852  2020-01-26      Sonoma    97                0       0
# 24853  2020-01-26  Stanislaus    99                0       0
# 24854  2020-01-26     Ventura   111                0       0
# 24855  2020-01-26        Yolo   113                0       0
#
#        new_confirmed_cases  new_deaths
# 0                     27.0         0.0
# 1                      0.0         0.0
# 2                      0.0         0.0
# 3                     26.0         0.0
# ...

# %%
cali_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24856 entries, 0 to 24855
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 24856 non-null  object
#  1   county               24856 non-null  object
#  2   fips                 24856 non-null  int64
#  3   confirmed_cases      24856 non-null  int64
#  4   deaths               24856 non-null  int64
#  5   new_confirmed_cases  24798 non-null  float64
#  6   new_deaths           24798 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.3+ MB

# %%
cali_counties.isna().sum()
# Out:
# date                    0
# county                  0
# fips                    0
# confirmed_cases         0
# deaths                  0
# new_confirmed_cases    58
# new_deaths             58
# dtype: int64

# %%
# get LA county
la_county = cali_counties.loc[cali_counties.county == 'Los Angeles']
la_county
# Out:
#              date       county  fips  confirmed_cases  deaths  \
# 18     2021-05-13  Los Angeles    37          1236469   24057
# 76     2021-05-12  Los Angeles    37          1236256   24041
# 134    2021-05-11  Los Angeles    37          1235999   24021
# 192    2021-05-10  Los Angeles    37          1235828   24003
# 250    2021-05-09  Los Angeles    37          1235651   23999
# ...           ...          ...   ...              ...     ...
# 24822  2020-01-30  Los Angeles    37                1       0
# 24825  2020-01-29  Los Angeles    37                1       0
# 24828  2020-01-28  Los Angeles    37                1       0
# 24831  2020-01-27  Los Angeles    37                1       0
# 24838  2020-01-26  Los Angeles    37                1       0
#
#        new_confirmed_cases  new_deaths
# 18                   213.0        16.0
# 76                   257.0        20.0
# 134                  171.0        18.0
# 192                  177.0         4.0
# ...

# %%
la_county['date'] = pd.to_datetime(la_county['date'])
la_county.set_index('date', inplace = True)
la_county.sort_index(inplace = True)
# Out:
# <ipython-input-13-c8030aea036c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   la_county['date'] = pd.to_datetime(la_county['date'])
# /Users/yuli/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/frame.py:5582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().sort_index(

# %%
la_county.head(2)
# Out:
#                  county  fips  confirmed_cases  deaths  new_confirmed_cases  \
# date
# 2020-01-26  Los Angeles    37                1       0                  NaN
# 2020-01-27  Los Angeles    37                1       0                  0.0
#
#             new_deaths
# date
# 2020-01-26         NaN
# 2020-01-27         0.0

# %%
la_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 474 entries, 2020-01-26 to 2021-05-13
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county               474 non-null    object
#  1   fips                 474 non-null    int64
#  2   confirmed_cases      474 non-null    int64
#  3   deaths               474 non-null    int64
#  4   new_confirmed_cases  473 non-null    float64
#  5   new_deaths           473 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 25.9+ KB

# %%
# locate only 2020 rows
la_county_2020 = la_county.loc['2020']
la_county_2020
# Out:
#                  county  fips  confirmed_cases  deaths  new_confirmed_cases  \
# date
# 2020-01-26  Los Angeles    37                1       0                  NaN
# 2020-01-27  Los Angeles    37                1       0                  0.0
# 2020-01-28  Los Angeles    37                1       0                  0.0
# 2020-01-29  Los Angeles    37                1       0                  0.0
# 2020-01-30  Los Angeles    37                1       0                  0.0
# ...                 ...   ...              ...     ...                  ...
# 2020-12-27  Los Angeles    37           719960    9485              12497.0
# 2020-12-28  Los Angeles    37           734860    9564              14900.0
# 2020-12-29  Los Angeles    37           746666    9806              11806.0
# 2020-12-30  Los Angeles    37           756840   10068              10174.0
# 2020-12-31  Los Angeles    37           771519   10359              14679.0
#
#             new_deaths
# date
# ...

# %%
# replace NaN with zeroes since on January 26 2020 there was only one covid-19
# case in LA on this date (first case), no death and no new cases
la_county_2020.replace({np.nan: 0}, inplace=True)
# Out:
# /Users/yuli/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
la_county_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 341 entries, 2020-01-26 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county               341 non-null    object
#  1   fips                 341 non-null    int64
#  2   confirmed_cases      341 non-null    int64
#  3   deaths               341 non-null    int64
#  4   new_confirmed_cases  341 non-null    float64
#  5   new_deaths           341 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 18.6+ KB

# %%
la_county_2020.head()
# Out:
#                  county  fips  confirmed_cases  deaths  new_confirmed_cases  \
# date
# 2020-01-26  Los Angeles    37                1       0                  0.0
# 2020-01-27  Los Angeles    37                1       0                  0.0
# 2020-01-28  Los Angeles    37                1       0                  0.0
# 2020-01-29  Los Angeles    37                1       0                  0.0
# 2020-01-30  Los Angeles    37                1       0                  0.0
#
#             new_deaths
# date
# 2020-01-26         0.0
# 2020-01-27         0.0
# 2020-01-28         0.0
# 2020-01-29         0.0
# 2020-01-30         0.0

# %%
# save df
la_county_2020.to_csv('./datasets/Covid-19-Data/LA_county_covid_2020.csv')

# %% [markdown]
# ---
# ### NYC data

# %%
nyc = pd.read_csv('./datasets/Covid-19-Data/NYC_COVID-19_Daily_Counts_of_Cases_Hospitalizations_and_Deaths.csv')
nyc
# Out:
#     DATE_OF_INTEREST  CASE_COUNT  probable_case_count  HOSPITALIZED_COUNT  \
# 0         02/29/2020           1                    0                   1
# 1         03/01/2020           0                    0                   1
# 2         03/02/2020           0                    0                   2
# 3         03/03/2020           1                    0                   7
# 4         03/04/2020           5                    0                   2
# ..               ...         ...                  ...                 ...
# 435       05/09/2021         311                  142                  47
# 436       05/10/2021         635                  188                  52
# 437       05/11/2021         595                  168                  48
# 438       05/12/2021         533                  138                  14
# 439       05/13/2021         411                  114                   5
#
#      DEATH_COUNT  DEATH_COUNT_PROBABLE  CASE_COUNT_7DAY_AVG  \
# ...

# %%
# make date in correct ISO8601 format
for i in range(0, nyc.shape[0]):
    nyc['DATE_OF_INTEREST'].iloc[i] = '-'.join([nyc['DATE_OF_INTEREST'][i].split('/')[2], nyc['DATE_OF_INTEREST'][i].split('/')[0], nyc['DATE_OF_INTEREST'][i].split('/')[1]])
# Out:
# /Users/yuli/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
nyc
# Out:
#     DATE_OF_INTEREST  CASE_COUNT  probable_case_count  HOSPITALIZED_COUNT  \
# 0         2020-02-29           1                    0                   1
# 1         2020-03-01           0                    0                   1
# 2         2020-03-02           0                    0                   2
# 3         2020-03-03           1                    0                   7
# 4         2020-03-04           5                    0                   2
# ..               ...         ...                  ...                 ...
# 435       2021-05-09         311                  142                  47
# 436       2021-05-10         635                  188                  52
# 437       2021-05-11         595                  168                  48
# 438       2021-05-12         533                  138                  14
# 439       2021-05-13         411                  114                   5
#
#      DEATH_COUNT  DEATH_COUNT_PROBABLE  CASE_COUNT_7DAY_AVG  \
# ...

# %%
nyc.rename(columns={'DATE_OF_INTEREST': 'date'}, inplace=True)
nyc['date'] = pd.to_datetime(nyc['date'])
nyc.set_index('date', inplace = True)
nyc.sort_index(inplace = True)

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 440 entries, 2020-02-29 to 2021-05-13
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CASE_COUNT                      440 non-null    int64
#  1   probable_case_count             440 non-null    int64
#  2   HOSPITALIZED_COUNT              440 non-null    int64
#  3   DEATH_COUNT                     440 non-null    int64
#  4   DEATH_COUNT_PROBABLE            440 non-null    int64
#  5   CASE_COUNT_7DAY_AVG             440 non-null    int64
#  6   all_case_count_7day_avg         440 non-null    int64
#  7   HOSP_COUNT_7DAY_AVG             440 non-null    int64
#  8   DEATH_COUNT_7DAY_AVG            440 non-null    int64
#  9   all_death_count_7day_avg        440 non-null    int64
#  10  BX_CASE_COUNT                   440 non-null    int64
#  11  bx_probable_case_count          440 non-null    int64
# ...

# %%
# locate only 2020 rows
# first case in NYC was on Feb 29 2020
nyc_boroughs_2020 = nyc.loc['2020']
nyc_boroughs_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 307 entries, 2020-02-29 to 2020-12-31
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CASE_COUNT                      307 non-null    int64
#  1   probable_case_count             307 non-null    int64
#  2   HOSPITALIZED_COUNT              307 non-null    int64
#  3   DEATH_COUNT                     307 non-null    int64
#  4   DEATH_COUNT_PROBABLE            307 non-null    int64
#  5   CASE_COUNT_7DAY_AVG             307 non-null    int64
#  6   all_case_count_7day_avg         307 non-null    int64
#  7   HOSP_COUNT_7DAY_AVG             307 non-null    int64
#  8   DEATH_COUNT_7DAY_AVG            307 non-null    int64
#  9   all_death_count_7day_avg        307 non-null    int64
#  10  BX_CASE_COUNT                   307 non-null    int64
#  11  bx_probable_case_count          307 non-null    int64
# ...

# %%
nyc_boroughs_2020.head(2)
# Out:
#             CASE_COUNT  probable_case_count  HOSPITALIZED_COUNT  DEATH_COUNT  \
# date
# 2020-02-29           1                    0                   1            0
# 2020-03-01           0                    0                   1            0
#
#             DEATH_COUNT_PROBABLE  CASE_COUNT_7DAY_AVG  \
# date
# 2020-02-29                     0                    0
# 2020-03-01                     0                    0
#
#             all_case_count_7day_avg  HOSP_COUNT_7DAY_AVG  \
# date
# 2020-02-29                        0                    0
# 2020-03-01                        0                    0
#
#             DEATH_COUNT_7DAY_AVG  all_death_count_7day_avg  ...  \
# date                                                        ...
# 2020-02-29                     0                         0  ...
# 2020-03-01                     0                         0  ...
#
#             si_probable_case_count  SI_HOSPITALIZED_COUNT  SI_DEATH_COUNT  \
# date
# ...

# %%
nyc_boroughs_2020.tail(2)
# Out:
#             CASE_COUNT  probable_case_count  HOSPITALIZED_COUNT  DEATH_COUNT  \
# date
# 2020-12-30        4975                 1062                 320           40
# 2020-12-31        3386                  780                 287           41
#
#             DEATH_COUNT_PROBABLE  CASE_COUNT_7DAY_AVG  \
# date
# 2020-12-30                     5                 3710
# 2020-12-31                     1                 3762
#
#             all_case_count_7day_avg  HOSP_COUNT_7DAY_AVG  \
# date
# 2020-12-30                     4614                  294
# 2020-12-31                     4687                  295
#
#             DEATH_COUNT_7DAY_AVG  all_death_count_7day_avg  ...  \
# date                                                        ...
# 2020-12-30                    41                        44  ...
# 2020-12-31                    42                        44  ...
#
#             si_probable_case_count  SI_HOSPITALIZED_COUNT  SI_DEATH_COUNT  \
# date
# ...

# %%
nyc_boroughs_2020.to_csv('./datasets/Covid-19-Data/NYC_all_boroughs_covid_2020.csv')
