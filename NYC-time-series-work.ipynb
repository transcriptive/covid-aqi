# %% [markdown]
# # NYC AQI Time Series Work

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read in the Data

# %%
NYC = pd.read_pickle('./datasets/air-quality-reports/aggregates/NYC.pkl')

# %%
NYC.head(10)
# Out:
#              AQI
# Date
# 2015-01-01  51.0
# 2015-01-02  56.8
# 2015-01-03  47.8
# 2015-01-04  42.2
# 2015-01-05  40.2
# 2015-01-06  47.4
# 2015-01-07  48.4
# 2015-01-08  41.2
# 2015-01-09  46.0
# 2015-01-10  53.8

# %% [markdown]
# ## Define train and test

# %%
train = NYC.loc[:'2019']

# %%
test = NYC.loc['2020']

# %% [markdown]
# ## Create Holt-Winters model predicting AQI for 2020

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# %%
predictions = test.copy(deep=True)

# %%
hw = ExponentialSmoothing(
    train['AQI'],
    seasonal_periods=365,
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# /Users/juliana/miniforge3/envs/tensorflow/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# /Users/juliana/miniforge3/envs/tensorflow/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                      AQI   No. Observations:                 1826
# Model:             ExponentialSmoothing   SSE                         467125.473
# Optimized:                         True   AIC                          10862.202
# Trend:                   Multiplicative   BIC                          12895.349
# Seasonal:                Multiplicative   AICC                         11052.040
# Seasonal Periods:                   365   Date:                 Mon, 17 May 2021
# Box-Cox:                          False   Time:                         14:50:34
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.0050000                alpha                 True
# smoothing_trend                   0.0001                 beta                 True
# smoothing_seasonal             0.3908929                gamma                 True
# initial_level                  39.666667                  l.0                 True
# initial_trend                  0.9998262                  b.0                 True
# initial_seasons.0              1.2857143                  s.0                 True
# initial_seasons.1              1.4319328                  s.1                 True
# initial_seasons.2              1.2050420                  s.2                 True
# initial_seasons.3              1.0638655                  s.3                 True
# initial_seasons.4              1.0134454                  s.4                 True
# initial_seasons.5              1.1949580                  s.5                 True
# initial_seasons.6              1.2201681                  s.6                 True
# initial_seasons.7              1.0386555                  s.7                 True
# initial_seasons.8              1.1596639                  s.8                 True
# initial_seasons.9              1.3563025                  s.9                 True
# initial_seasons.10             1.4016807                 s.10                 True
# initial_seasons.11             1.5126050                 s.11                 True
# initial_seasons.12             1.2504202                 s.12                 True
# initial_seasons.13             1.4420168                 s.13                 True
# initial_seasons.14             1.5680672                 s.14                 True
# initial_seasons.15             1.5075630                 s.15                 True
# initial_seasons.16             0.9831933                 s.16                 True
# initial_seasons.17             1.6184874                 s.17                 True
# initial_seasons.18             1.0638655                 s.18                 True
# initial_seasons.19             1.0336134                 s.19                 True
# initial_seasons.20             1.2605042                 s.20                 True
# initial_seasons.21             1.3865546                 s.21                 True
# initial_seasons.22             1.4974790                 s.22                 True
# initial_seasons.23             1.4722689                 s.23                 True
# initial_seasons.24             1.0739496                 s.24                 True
# initial_seasons.25             1.1344538                 s.25                 True
# initial_seasons.26             0.9529412                 s.26                 True
# initial_seasons.27             1.0638655                 s.27                 True
# initial_seasons.28             1.1193277                 s.28                 True
# initial_seasons.29             1.1243697                 s.29                 True
# initial_seasons.30             0.9731092                 s.30                 True
# initial_seasons.31             1.4571429                 s.31                 True
# initial_seasons.32             1.1495798                 s.32                 True
# initial_seasons.33             1.2352941                 s.33                 True
# initial_seasons.34             1.5126050                 s.34                 True
# initial_seasons.35             1.3462185                 s.35                 True
# initial_seasons.36             1.3058824                 s.36                 True
# initial_seasons.37             1.6285714                 s.37                 True
# initial_seasons.38             1.9815126                 s.38                 True
# initial_seasons.39             1.0436975                 s.39                 True
# initial_seasons.40             0.9126050                 s.40                 True
# initial_seasons.41             1.1899160                 s.41                 True
# initial_seasons.42             1.3462185                 s.42                 True
# initial_seasons.43             1.0991597                 s.43                 True
# initial_seasons.44             1.3260504                 s.44                 True
# initial_seasons.45             1.2655462                 s.45                 True
# initial_seasons.46             1.0235294                 s.46                 True
# initial_seasons.47             1.5176471                 s.47                 True
# initial_seasons.48             1.6235294                 s.48                 True
# initial_seasons.49             1.1495798                 s.49                 True
# initial_seasons.50             1.2554622                 s.50                 True
# initial_seasons.51             1.2302521                 s.51                 True
# initial_seasons.52             1.7243697                 s.52                 True
# initial_seasons.53             1.2050420                 s.53                 True
# initial_seasons.54             1.0336134                 s.54                 True
# initial_seasons.55             1.4621849                 s.55                 True
# initial_seasons.56             1.1697479                 s.56                 True
# initial_seasons.57             1.2857143                 s.57                 True
# initial_seasons.58             1.1798319                 s.58                 True
# initial_seasons.59             1.4571429                 s.59                 True
# initial_seasons.60             1.4369748                 s.60                 True
# initial_seasons.61             0.9277311                 s.61                 True
# initial_seasons.62             1.9411765                 s.62                 True
# initial_seasons.63             1.1697479                 s.63                 True
# initial_seasons.64             1.0991597                 s.64                 True
# initial_seasons.65             1.6890756                 s.65                 True
# initial_seasons.66             1.5176471                 s.66                 True
# initial_seasons.67             1.4873950                 s.67                 True
# initial_seasons.68             2.1126050                 s.68                 True
# initial_seasons.69             1.3159664                 s.69                 True
# initial_seasons.70             0.7310924                 s.70                 True
# initial_seasons.71             0.8168067                 s.71                 True
# initial_seasons.72             0.7462185                 s.72                 True
# initial_seasons.73             0.6907563                 s.73                 True
# initial_seasons.74             1.2705882                 s.74                 True
# initial_seasons.75             1.2907563                 s.75                 True
# initial_seasons.76             0.6857143                 s.76                 True
# initial_seasons.77             0.7915966                 s.77                 True
# initial_seasons.78             0.8369748                 s.78                 True
# initial_seasons.79             1.3008403                 s.79                 True
# initial_seasons.80             0.8168067                 s.80                 True
# initial_seasons.81             0.7966387                 s.81                 True
# initial_seasons.82             1.0487395                 s.82                 True
# initial_seasons.83             1.5277311                 s.83                 True
# initial_seasons.84             1.3310924                 s.84                 True
# initial_seasons.85             0.6050420                 s.85                 True
# initial_seasons.86             0.8974790                 s.86                 True
# initial_seasons.87             0.7966387                 s.87                 True
# initial_seasons.88             0.8117647                 s.88                 True
# initial_seasons.89             0.7512605                 s.89                 True
# initial_seasons.90             0.8974790                 s.90                 True
# initial_seasons.91             1.3714286                 s.91                 True
# initial_seasons.92             1.3764706                 s.92                 True
# initial_seasons.93             0.7764706                 s.93                 True
# initial_seasons.94             0.9428571                 s.94                 True
# initial_seasons.95             1.2504202                 s.95                 True
# initial_seasons.96             1.2907563                 s.96                 True
# initial_seasons.97             0.7411765                 s.97                 True
# initial_seasons.98             0.8873950                 s.98                 True
# initial_seasons.99             0.9126050                 s.99                 True
# initial_seasons.100            0.8873950                s.100                 True
# initial_seasons.101            1.0084034                s.101                 True
# initial_seasons.102            1.1344538                s.102                 True
# initial_seasons.103            0.9882353                s.103                 True
# initial_seasons.104            0.9680672                s.104                 True
# initial_seasons.105            0.9176471                s.105                 True
# initial_seasons.106            0.9831933                s.106                 True
# initial_seasons.107            1.4016807                s.107                 True
# initial_seasons.108            0.8117647                s.108                 True
# initial_seasons.109            0.7764706                s.109                 True
# initial_seasons.110            1.0840336                s.110                 True
# initial_seasons.111            1.0588235                s.111                 True
# initial_seasons.112            0.6705882                s.112                 True
# initial_seasons.113            0.7663866                s.113                 True
# initial_seasons.114            0.8369748                s.114                 True
# initial_seasons.115            0.8319328                s.115                 True
# initial_seasons.116            0.6957983                s.116                 True
# initial_seasons.117            0.9176471                s.117                 True
# initial_seasons.118            0.9882353                s.118                 True
# initial_seasons.119            0.7966387                s.119                 True
# initial_seasons.120            0.7058824                s.120                 True
# initial_seasons.121            0.8571429                s.121                 True
# initial_seasons.122            1.1294118                s.122                 True
# initial_seasons.123            1.6689076                s.123                 True
# initial_seasons.124            1.9058824                s.124                 True
# initial_seasons.125            1.0890756                s.125                 True
# initial_seasons.126            1.3361345                s.126                 True
# initial_seasons.127            1.5327731                s.127                 True
# initial_seasons.128            1.4369748                s.128                 True
# initial_seasons.129            1.1344538                s.129                 True
# initial_seasons.130            1.7445378                s.130                 True
# initial_seasons.131            1.3714286                s.131                 True
# initial_seasons.132            0.6352941                s.132                 True
# initial_seasons.133            1.0033613                s.133                 True
# initial_seasons.134            1.2756303                s.134                 True
# initial_seasons.135            1.2907563                s.135                 True
# initial_seasons.136            1.8050420                s.136                 True
# initial_seasons.137            1.4067227                s.137                 True
# initial_seasons.138            1.2907563                s.138                 True
# initial_seasons.139            0.6403361                s.139                 True
# initial_seasons.140            0.7815126                s.140                 True
# initial_seasons.141            1.0235294                s.141                 True
# initial_seasons.142            0.9277311                s.142                 True
# initial_seasons.143            1.6739496                s.143                 True
# initial_seasons.144            1.4974790                s.144                 True
# initial_seasons.145            1.2655462                s.145                 True
# initial_seasons.146            1.1193277                s.146                 True
# initial_seasons.147            1.2453782                s.147                 True
# initial_seasons.148            0.9126050                s.148                 True
# initial_seasons.149            0.7361345                s.149                 True
# initial_seasons.150            0.7462185                s.150                 True
# initial_seasons.151            0.4386555                s.151                 True
# initial_seasons.152            0.3983193                s.152                 True
# initial_seasons.153            0.5798319                s.153                 True
# initial_seasons.154            0.6151261                s.154                 True
# initial_seasons.155            0.9428571                s.155                 True
# initial_seasons.156            0.9378151                s.156                 True
# initial_seasons.157            0.8218487                s.157                 True
# initial_seasons.158            0.9378151                s.158                 True
# initial_seasons.159            1.2302521                s.159                 True
# initial_seasons.160            1.4571429                s.160                 True
# initial_seasons.161            2.8739496                s.161                 True
# initial_seasons.162            1.7394958                s.162                 True
# initial_seasons.163            0.9831933                s.163                 True
# initial_seasons.164            2.2638655                s.164                 True
# initial_seasons.165            0.8924370                s.165                 True
# initial_seasons.166            1.0336134                s.166                 True
# initial_seasons.167            0.8420168                s.167                 True
# initial_seasons.168            0.7008403                s.168                 True
# initial_seasons.169            0.9983193                s.169                 True
# initial_seasons.170            0.8924370                s.170                 True
# initial_seasons.171            0.7764706                s.171                 True
# initial_seasons.172            1.2957983                s.172                 True
# initial_seasons.173            1.5731092                s.173                 True
# initial_seasons.174            0.7865546                s.174                 True
# initial_seasons.175            0.9579832                s.175                 True
# initial_seasons.176            1.2907563                s.176                 True
# initial_seasons.177            0.6705882                s.177                 True
# initial_seasons.178            0.5697479                s.178                 True
# initial_seasons.179            0.7058824                s.179                 True
# initial_seasons.180            0.9831933                s.180                 True
# initial_seasons.181            1.8302521                s.181                 True
# initial_seasons.182            1.2857143                s.182                 True
# initial_seasons.183            1.3865546                s.183                 True
# initial_seasons.184            1.1697479                s.184                 True
# initial_seasons.185            1.6033613                s.185                 True
# initial_seasons.186            1.0991597                s.186                 True
# initial_seasons.187            1.3008403                s.187                 True
# initial_seasons.188            1.6084034                s.188                 True
# initial_seasons.189            1.3008403                s.189                 True
# initial_seasons.190            1.0033613                s.190                 True
# initial_seasons.191            1.4420168                s.191                 True
# initial_seasons.192            1.6235294                s.192                 True
# initial_seasons.193            1.2050420                s.193                 True
# initial_seasons.194            1.1596639                s.194                 True
# initial_seasons.195            1.0890756                s.195                 True
# initial_seasons.196            0.9983193                s.196                 True
# initial_seasons.197            1.0739496                s.197                 True
# initial_seasons.198            1.0487395                s.198                 True
# initial_seasons.199            2.2134454                s.199                 True
# initial_seasons.200            1.6840336                s.200                 True
# initial_seasons.201            1.3563025                s.201                 True
# initial_seasons.202            0.7663866                s.202                 True
# initial_seasons.203            0.9327731                s.203                 True
# initial_seasons.204            1.2554622                s.204                 True
# initial_seasons.205            1.3260504                s.205                 True
# initial_seasons.206            1.3764706                s.206                 True
# initial_seasons.207            1.0840336                s.207                 True
# initial_seasons.208            2.0974790                s.208                 True
# initial_seasons.209            2.2537815                s.209                 True
# initial_seasons.210            1.2201681                s.210                 True
# initial_seasons.211            0.8974790                s.211                 True
# initial_seasons.212            1.3512605                s.212                 True
# initial_seasons.213            1.2302521                s.213                 True
# initial_seasons.214            1.6436975                s.214                 True
# initial_seasons.215            1.4873950                s.215                 True
# initial_seasons.216            1.2100840                s.216                 True
# initial_seasons.217            0.8773109                s.217                 True
# initial_seasons.218            0.8823529                s.218                 True
# initial_seasons.219            0.8117647                s.219                 True
# initial_seasons.220            0.7815126                s.220                 True
# initial_seasons.221            0.6403361                s.221                 True
# initial_seasons.222            0.7008403                s.222                 True
# initial_seasons.223            0.7815126                s.223                 True
# initial_seasons.224            0.8924370                s.224                 True
# initial_seasons.225            1.4924370                s.225                 True
# initial_seasons.226            2.5815126                s.226                 True
# initial_seasons.227            2.3344538                s.227                 True
# initial_seasons.228            2.1781513                s.228                 True
# initial_seasons.229            1.1142857                s.229                 True
# initial_seasons.230            0.6655462                s.230                 True
# initial_seasons.231            0.4890756                s.231                 True
# initial_seasons.232            1.2000000                s.232                 True
# initial_seasons.233            1.1848739                s.233                 True
# initial_seasons.234            0.8319328                s.234                 True
# initial_seasons.235            1.6739496                s.235                 True
# initial_seasons.236            1.6689076                s.236                 True
# initial_seasons.237            1.0184874                s.237                 True
# initial_seasons.238            0.7260504                s.238                 True
# initial_seasons.239            0.8722689                s.239                 True
# initial_seasons.240            1.7495798                s.240                 True
# initial_seasons.241            1.8352941                s.241                 True
# initial_seasons.242            1.7243697                s.242                 True
# initial_seasons.243            1.7596639                s.243                 True
# initial_seasons.244            1.8756303                s.244                 True
# initial_seasons.245            2.5008403                s.245                 True
# initial_seasons.246            1.5428571                s.246                 True
# initial_seasons.247            0.6453782                s.247                 True
# initial_seasons.248            0.8672269                s.248                 True
# initial_seasons.249            1.3815126                s.249                 True
# initial_seasons.250            1.6890756                s.250                 True
# initial_seasons.251            0.8117647                s.251                 True
# initial_seasons.252            0.6857143                s.252                 True
# initial_seasons.253            0.7865546                s.253                 True
# initial_seasons.254            0.8722689                s.254                 True
# initial_seasons.255            0.6201681                s.255                 True
# initial_seasons.256            0.6000000                s.256                 True
# initial_seasons.257            1.2554622                s.257                 True
# initial_seasons.258            1.7697479                s.258                 True
# initial_seasons.259            2.9747899                s.259                 True
# initial_seasons.260            2.1529412                s.260                 True
# initial_seasons.261            0.9378151                s.261                 True
# initial_seasons.262            0.6201681                s.262                 True
# initial_seasons.263            0.7159664                s.263                 True
# initial_seasons.264            0.6453782                s.264                 True
# initial_seasons.265            0.9126050                s.265                 True
# initial_seasons.266            1.0235294                s.266                 True
# initial_seasons.267            0.6151261                s.267                 True
# initial_seasons.268            0.6806723                s.268                 True
# initial_seasons.269            0.6756303                s.269                 True
# initial_seasons.270            0.6806723                s.270                 True
# initial_seasons.271            0.6857143                s.271                 True
# initial_seasons.272            0.4789916                s.272                 True
# initial_seasons.273            0.3781513                s.273                 True
# initial_seasons.274            0.3630252                s.274                 True
# initial_seasons.275            0.4386555                s.275                 True
# initial_seasons.276            0.6403361                s.276                 True
# initial_seasons.277            0.6050420                s.277                 True
# initial_seasons.278            0.8420168                s.278                 True
# initial_seasons.279            0.7008403                s.279                 True
# initial_seasons.280            0.8470588                s.280                 True
# initial_seasons.281            0.9731092                s.281                 True
# initial_seasons.282            0.7109244                s.282                 True
# initial_seasons.283            0.7966387                s.283                 True
# initial_seasons.284            1.0739496                s.284                 True
# initial_seasons.285            0.9378151                s.285                 True
# initial_seasons.286            0.5546218                s.286                 True
# initial_seasons.287            0.6000000                s.287                 True
# initial_seasons.288            0.7058824                s.288                 True
# initial_seasons.289            0.5042017                s.289                 True
# initial_seasons.290            0.5596639                s.290                 True
# initial_seasons.291            0.6957983                s.291                 True
# initial_seasons.292            0.9327731                s.292                 True
# initial_seasons.293            1.4420168                s.293                 True
# initial_seasons.294            1.3865546                s.294                 True
# initial_seasons.295            0.7411765                s.295                 True
# initial_seasons.296            0.5546218                s.296                 True
# initial_seasons.297            0.5092437                s.297                 True
# initial_seasons.298            0.9075630                s.298                 True
# initial_seasons.299            0.7714286                s.299                 True
# initial_seasons.300            0.5647059                s.300                 True
# initial_seasons.301            0.6806723                s.301                 True
# initial_seasons.302            0.5848739                s.302                 True
# initial_seasons.303            0.6655462                s.303                 True
# initial_seasons.304            1.0789916                s.304                 True
# initial_seasons.305            1.2201681                s.305                 True
# initial_seasons.306            1.4722689                s.306                 True
# initial_seasons.307            1.4823529                s.307                 True
# initial_seasons.308            1.7848739                s.308                 True
# initial_seasons.309            1.1394958                s.309                 True
# initial_seasons.310            0.6201681                s.310                 True
# initial_seasons.311            0.6857143                s.311                 True
# initial_seasons.312            1.1546218                s.312                 True
# initial_seasons.313            0.7613445                s.313                 True
# initial_seasons.314            0.5394958                s.314                 True
# initial_seasons.315            0.6504202                s.315                 True
# initial_seasons.316            0.6403361                s.316                 True
# initial_seasons.317            0.6504202                s.317                 True
# initial_seasons.318            0.7764706                s.318                 True
# initial_seasons.319            1.2554622                s.319                 True
# initial_seasons.320            0.8067227                s.320                 True
# initial_seasons.321            0.6201681                s.321                 True
# initial_seasons.322            0.6504202                s.322                 True
# initial_seasons.323            0.6302521                s.323                 True
# initial_seasons.324            0.7008403                s.324                 True
# initial_seasons.325            0.6655462                s.325                 True
# initial_seasons.326            0.6050420                s.326                 True
# initial_seasons.327            1.0789916                s.327                 True
# initial_seasons.328            1.3512605                s.328                 True
# initial_seasons.329            1.3865546                s.329                 True
# initial_seasons.330            0.8773109                s.330                 True
# initial_seasons.331            0.8924370                s.331                 True
# initial_seasons.332            0.6453782                s.332                 True
# initial_seasons.333            0.8924370                s.333                 True
# initial_seasons.334            0.7159664                s.334                 True
# initial_seasons.335            1.1848739                s.335                 True
# initial_seasons.336            0.7865546                s.336                 True
# initial_seasons.337            0.9680672                s.337                 True
# initial_seasons.338            1.3764706                s.338                 True
# initial_seasons.339            1.6588235                s.339                 True
# initial_seasons.340            1.8403361                s.340                 True
# initial_seasons.341            1.3714286                s.341                 True
# initial_seasons.342            1.5226891                s.342                 True
# initial_seasons.343            1.5478992                s.343                 True
# initial_seasons.344            1.8857143                s.344                 True
# initial_seasons.345            2.0420168                s.345                 True
# initial_seasons.346            1.8302521                s.346                 True
# initial_seasons.347            1.1193277                s.347                 True
# initial_seasons.348            0.5647059                s.348                 True
# initial_seasons.349            0.6000000                s.349                 True
# initial_seasons.350            0.7865546                s.350                 True
# initial_seasons.351            0.7764706                s.351                 True
# initial_seasons.352            0.8117647                s.352                 True
# initial_seasons.353            0.9075630                s.353                 True
# initial_seasons.354            0.9680672                s.354                 True
# initial_seasons.355            1.1647059                s.355                 True
# initial_seasons.356            1.2554622                s.356                 True
# initial_seasons.357            1.0386555                s.357                 True
# initial_seasons.358            1.4873950                s.358                 True
# initial_seasons.359            0.7058824                s.359                 True
# initial_seasons.360            0.8319328                s.360                 True
# initial_seasons.361            0.6705882                s.361                 True
# initial_seasons.362            0.7915966                s.362                 True
# initial_seasons.363            1.0134454                s.363                 True
# initial_seasons.364            0.9126050                s.364                 True
# ----------------------------------------------------------------------------------
# """

# %%
predictions['hw'] = hw.forecast(len(test))

# %%
hw.predict(len(test))
# Out:
# 2015-10-03    16.957921
# 2015-10-04    24.753646
# 2015-10-05    23.388313
# 2015-10-06    32.547409
# 2015-10-07    27.089260
#                 ...
# 2019-12-27    38.211073
# 2019-12-28    33.326159
# 2019-12-29    33.954906
# 2019-12-30    40.699360
# 2019-12-31    42.311202
# Freq: D, Length: 1551, dtype: float64

# %%
predictions['hw']
# Out:
# Date
# 2020-01-01    44.367529
# 2020-01-02    45.664382
# 2020-01-03    42.154516
# 2020-01-04    45.650944
# 2020-01-05    42.383633
#                 ...
# 2020-09-27    28.844393
# 2020-09-28    26.736267
# 2020-09-29    23.160332
# 2020-09-30    29.819817
# 2020-10-01    33.416557
# Name: hw, Length: 275, dtype: float64

# %%
plt.figure(figsize = (16, 4))
plt.plot(train['AQI'].loc['2019'], label = 'Historical AQI')
plt.plot(predictions['AQI'], label = 'Actual AQI')
plt.plot(predictions['hw'], label = 'Predicted AQI')
plt.title('AQI for New York City')
plt.legend();

# %% [markdown]
# ## Gonna try weekly now

# %%
train_wk = train.resample('W').mean()

# %%
test_wk = test.resample('W').mean()

# %%
train_wk.head()
# Out:
#                   AQI
# Date
# 2015-01-04  49.450000
# 2015-01-11  47.514286
# 2015-01-18  56.000000
# 2015-01-25  49.800000
# 2015-02-01  44.342857

# %%
hw2 = ExponentialSmoothing(
    train_wk['AQI'],
    seasonal_periods=52,
    trend='add',
    seasonal='add'
).fit()

# %%
hw2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                      AQI   No. Observations:                  262
# Model:             ExponentialSmoothing   SSE                          11838.691
# Optimized:                         True   AIC                           1110.425
# Trend:                         Additive   BIC                           1310.253
# Seasonal:                      Additive   AICC                          1144.140
# Seasonal Periods:                    52   Date:                 Mon, 17 May 2021
# Box-Cox:                          False   Time:                         15:28:51
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level              6.9323e-06                alpha                 True
# smoothing_trend              6.5786e-06                 beta                 True
# smoothing_seasonal           5.8403e-06                gamma                 True
# initial_level                 43.308820                  l.0                 True
# initial_trend                -0.0249881                  b.0                 True
# initial_seasons.0             3.4712271                  s.0                 True
# initial_seasons.1             2.9075389                  s.1                 True
# initial_seasons.2             5.7540488                  s.2                 True
# initial_seasons.3             6.6068930                  s.3                 True
# initial_seasons.4             1.5311847                  s.4                 True
# initial_seasons.5             5.2919137                  s.5                 True
# initial_seasons.6             3.3733106                  s.6                 True
# initial_seasons.7             2.7504352                  s.7                 True
# initial_seasons.8            -0.9595071                  s.8                 True
# initial_seasons.9             0.2208355                  s.9                 True
# initial_seasons.10            1.5133504                 s.10                 True
# initial_seasons.11           -3.6938955                 s.11                 True
# initial_seasons.12           -1.4324222                 s.12                 True
# initial_seasons.13           -1.6714641                 s.13                 True
# initial_seasons.14           -3.6148907                 s.14                 True
# initial_seasons.15            1.7272125                 s.15                 True
# initial_seasons.16           -3.1904954                 s.16                 True
# initial_seasons.17           -4.8115297                 s.17                 True
# initial_seasons.18            1.6740259                 s.18                 True
# initial_seasons.19           -1.2130376                 s.19                 True
# initial_seasons.20            1.5139347                 s.20                 True
# initial_seasons.21            6.1941414                 s.21                 True
# initial_seasons.22           -4.8226157                 s.22                 True
# initial_seasons.23            6.8009459                 s.23                 True
# initial_seasons.24            2.4173253                 s.24                 True
# initial_seasons.25            4.4453970                 s.25                 True
# initial_seasons.26            9.1477314                 s.26                 True
# initial_seasons.27            11.024673                 s.27                 True
# initial_seasons.28            13.391461                 s.28                 True
# initial_seasons.29            15.511096                 s.29                 True
# initial_seasons.30            7.0745227                 s.30                 True
# initial_seasons.31            5.3377148                 s.31                 True
# initial_seasons.32            9.9586154                 s.32                 True
# initial_seasons.33            4.7636141                 s.33                 True
# initial_seasons.34            3.2040128                 s.34                 True
# initial_seasons.35            3.9332370                 s.35                 True
# initial_seasons.36           -2.1596996                 s.36                 True
# initial_seasons.37            0.7516258                 s.37                 True
# initial_seasons.38           -5.6412966                 s.38                 True
# initial_seasons.39           -11.077381                 s.39                 True
# initial_seasons.40           -6.7860011                 s.40                 True
# initial_seasons.41           -12.144572                 s.41                 True
# initial_seasons.42           -6.9008226                 s.42                 True
# initial_seasons.43           -9.7194895                 s.43                 True
# initial_seasons.44           -5.6746941                 s.44                 True
# initial_seasons.45           -9.1958758                 s.45                 True
# initial_seasons.46           -3.9527281                 s.46                 True
# initial_seasons.47           -4.0094112                 s.47                 True
# initial_seasons.48           -3.0222407                 s.48                 True
# initial_seasons.49            3.0086286                 s.49                 True
# initial_seasons.50            0.7963977                 s.50                 True
# initial_seasons.51            2.8559898                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
weekly_preds = test_wk.copy(deep=True)

# %%
weekly_preds['hw'] = hw2.forecast(len(test_wk))

# %%
plt.figure(figsize = (18, 4))
plt.plot(train_wk['AQI'].loc['2019'], label = 'Historical AQI')
plt.plot(weekly_preds['AQI'], label = 'Actual AQI')
plt.plot(weekly_preds['hw'], label = 'Predicted AQI')
plt.title('Weekly average AQI for New York City')
plt.legend();
