# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
aqi_2015 = pd.read_csv('./datasets/air-quality-reports/2015/daily_aqi_by_county_2015.csv')
aqi_2016 = pd.read_csv('./datasets/air-quality-reports/2016/daily_aqi_by_county_2016.csv')
aqi_2017 = pd.read_csv('./datasets/air-quality-reports/2017/daily_aqi_by_county_2017.csv')
aqi_2018 = pd.read_csv('./datasets/air-quality-reports/2018/daily_aqi_by_county_2018.csv')
aqi_2019 = pd.read_csv('./datasets/air-quality-reports/2019/daily_aqi_by_county_2019.csv')
aqi_2020 = pd.read_csv('./datasets/air-quality-reports/2020/daily_aqi_by_county_2020.csv')

# %%
aqi_2015.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI  Category  \
# 0    Alabama     Baldwin           1            3  2015-01-03   28      Good
# 1    Alabama     Baldwin           1            3  2015-01-06   48      Good
# 2    Alabama     Baldwin           1            3  2015-01-09   55  Moderate
# 3    Alabama     Baldwin           1            3  2015-01-12   41      Good
# 4    Alabama     Baldwin           1            3  2015-01-15   26      Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2016.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2016-01-01   33     Good
# 1    Alabama     Baldwin           1            3  2016-01-04   22     Good
# 2    Alabama     Baldwin           1            3  2016-01-07   28     Good
# 3    Alabama     Baldwin           1            3  2016-01-10   13     Good
# 4    Alabama     Baldwin           1            3  2016-01-13   36     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2017.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2017-01-01   21     Good
# 1    Alabama     Baldwin           1            3  2017-01-04   22     Good
# 2    Alabama     Baldwin           1            3  2017-01-10   19     Good
# 3    Alabama     Baldwin           1            3  2017-01-13   30     Good
# 4    Alabama     Baldwin           1            3  2017-01-16   16     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2018.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2018-01-02   32     Good
# 1    Alabama     Baldwin           1            3  2018-01-05   34     Good
# 2    Alabama     Baldwin           1            3  2018-01-08   15     Good
# 3    Alabama     Baldwin           1            3  2018-01-11   19     Good
# 4    Alabama     Baldwin           1            3  2018-01-14   25     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2019.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2019-01-03   18     Good
# 1    Alabama     Baldwin           1            3  2019-01-06   35     Good
# 2    Alabama     Baldwin           1            3  2019-01-09   14     Good
# 3    Alabama     Baldwin           1            3  2019-01-12   36     Good
# 4    Alabama     Baldwin           1            3  2019-01-15   38     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2020.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2020-01-01   48     Good
# 1    Alabama     Baldwin           1            3  2020-01-04   13     Good
# 2    Alabama     Baldwin           1            3  2020-01-07   14     Good
# 3    Alabama     Baldwin           1            3  2020-01-10   39     Good
# 4    Alabama     Baldwin           1            3  2020-01-13   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2015['Date'] = pd.to_datetime(aqi_2015['Date'])

# %%
aqi_2016['Date'] = pd.to_datetime(aqi_2016['Date'])
aqi_2017['Date'] = pd.to_datetime(aqi_2017['Date'])
aqi_2018['Date'] = pd.to_datetime(aqi_2018['Date'])
aqi_2019['Date'] = pd.to_datetime(aqi_2019['Date'])
aqi_2020['Date'] = pd.to_datetime(aqi_2020['Date'])

# %%
aqi_2015.set_index('Date', inplace=True)
aqi_2016.set_index('Date', inplace=True)
aqi_2017.set_index('Date', inplace=True)
aqi_2018.set_index('Date', inplace=True)
aqi_2019.set_index('Date', inplace=True)
aqi_2020.set_index('Date', inplace=True)

# %%
aqi_2015.head(1)
# Out:
#            State Name county Name  State Code  County Code  AQI Category  \
# Date
# 2015-01-03    Alabama     Baldwin           1            3   28     Good
#
#            Defining Parameter Defining Site  Number of Sites Reporting
# Date
# 2015-01-03              PM2.5   01-003-0010                          1

# %%
aqi_2015_2020 = pd.concat([aqi_2015, aqi_2016, aqi_2017, aqi_2018, aqi_2019, aqi_2020])

# %%
aqi_2015_2020
# Out:
#            State Name county Name  State Code  County Code  AQI  Category  \
# Date
# 2015-01-03    Alabama     Baldwin           1            3   28      Good
# 2015-01-06    Alabama     Baldwin           1            3   48      Good
# 2015-01-09    Alabama     Baldwin           1            3   55  Moderate
# 2015-01-12    Alabama     Baldwin           1            3   41      Good
# 2015-01-15    Alabama     Baldwin           1            3   26      Good
# ...               ...         ...         ...          ...  ...       ...
# 2020-06-26    Wyoming      Weston          56           45   43      Good
# 2020-06-27    Wyoming      Weston          56           45   61  Moderate
# 2020-06-28    Wyoming      Weston          56           45   49      Good
# 2020-06-29    Wyoming      Weston          56           45   54  Moderate
# 2020-06-30    Wyoming      Weston          56           45   44      Good
#
#            Defining Parameter Defining Site  Number of Sites Reporting
# Date
# 2015-01-03              PM2.5   01-003-0010                          1
# 2015-01-06              PM2.5   01-003-0010                          1
# 2015-01-09              PM2.5   01-003-0010                          1
# 2015-01-12              PM2.5   01-003-0010                          1
# 2015-01-15              PM2.5   01-003-0010                          1
# ...                       ...           ...                        ...
# 2020-06-26              Ozone   56-045-0003                          2
# 2020-06-27              Ozone   56-045-0003                          2
# 2020-06-28              Ozone   56-045-0003                          2
# 2020-06-29              Ozone   56-045-0003                          2
# 2020-06-30              Ozone   56-045-0003                          2
#
# [1905135 rows x 9 columns]

# %%
aqi_2015_2020.sort_index(inplace=True)

# %%
aqi_2015_2020
# Out:
#                 State Name   county Name  State Code  County Code  AQI  \
# Date
# 2015-01-01         Indiana      Hamilton          18           57   31
# 2015-01-01  South Carolina      Colleton          45           29   44
# 2015-01-01  North Carolina     Edgecombe          37           65   38
# 2015-01-01  South Carolina  Chesterfield          45           25   48
# 2015-01-01        Michigan         Wayne          26          163   48
# ...                    ...           ...         ...          ...  ...
# 2020-11-01            Utah     Salt Lake          49           35    8
# 2020-11-01           Maine       Hancock          23            9    1
# 2020-11-02  South Carolina      Anderson          45            7   33
# 2020-11-03  South Carolina      Anderson          45            7   29
# 2020-11-04  South Carolina      Anderson          45            7   36
#
#            Category Defining Parameter Defining Site  \
# Date
# 2015-01-01     Good              PM2.5   18-057-0007
# 2015-01-01     Good              PM2.5   45-029-0002
# 2015-01-01     Good              PM2.5   37-065-0099
# 2015-01-01     Good              PM2.5   45-025-0001
# 2015-01-01     Good              PM2.5   26-163-0033
# ...             ...                ...           ...
# 2020-11-01     Good                 CO   49-035-3006
# 2020-11-01     Good                 CO   23-009-0103
# 2020-11-02     Good              Ozone   45-007-0006
# 2020-11-03     Good              Ozone   45-007-0006
# 2020-11-04     Good              Ozone   45-007-0006
#
#             Number of Sites Reporting
# Date
# 2015-01-01                          1
# 2015-01-01                          1
# 2015-01-01                          1
# 2015-01-01                          1
# 2015-01-01                         12
# ...                               ...
# 2020-11-01                          4
# 2020-11-01                          1
# 2020-11-02                          2
# 2020-11-03                          1
# 2020-11-04                          1
#
# [1905135 rows x 9 columns]

# %%
aqi_NYS = aqi_2015_2020[aqi_2015_2020['State Name']== 'New York']

# %%
aqi_NYS.drop(columns='State Code', inplace = True)
# Out:
# /Users/juliana/miniforge3/envs/tensorflow/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
aqi_NYC = pd.concat(
    [aqi_NYS[aqi_NYS['county Name'] == 'New York'],
     aqi_NYS[aqi_NYS['county Name'] == 'Kings'],
     aqi_NYS[aqi_NYS['county Name'] == 'Queens'],
     aqi_NYS[aqi_NYS['county Name'] == 'Bronx'],
     aqi_NYS[aqi_NYS['county Name'] == 'Richmond']]
)

# %%
aqi_NYC.sort_index(inplace=True)

# %%
aqi_NYC
# Out:
#            State Name county Name  County Code  AQI  Category  \
# Date
# 2015-01-01   New York    New York           61   63  Moderate
# 2015-01-01   New York      Queens           81   44      Good
# 2015-01-01   New York    Richmond           85   52  Moderate
# 2015-01-01   New York       Kings           47   44      Good
# 2015-01-01   New York       Bronx            5   52  Moderate
# ...               ...         ...          ...  ...       ...
# 2020-09-30   New York      Queens           81   16      Good
# 2020-09-30   New York    Richmond           85   31      Good
# 2020-10-01   New York       Bronx            5    3      Good
# 2020-10-01   New York    New York           61    3      Good
# 2020-10-01   New York      Queens           81    2      Good
#
#            Defining Parameter Defining Site  Number of Sites Reporting
# Date
# 2015-01-01              PM2.5   36-061-0115                          4
# 2015-01-01              PM2.5   36-081-0120                          2
# 2015-01-01              PM2.5   36-085-0055                          2
# 2015-01-01              PM2.5   36-047-0118                          2
# 2015-01-01              PM2.5   36-005-0080                          4
# ...                       ...           ...                        ...
# 2020-09-30                NO2   36-081-0125                          2
# 2020-09-30              Ozone   36-085-0111                          2
# 2020-10-01                 CO   36-005-0133                          1
# 2020-10-01                 CO   36-061-0135                          1
# 2020-10-01                 CO   36-081-0125                          1
#
# [10477 rows x 8 columns]

# %%
aqi_NYC_agg = aqi_NYC.copy(deep = True)

# %%
aqi_NYC_agg.drop(columns=['State Name', 'county Name', 'County Code', 'Number of Sites Reporting', 'Category', 'Defining Parameter', 'Defining Site'], inplace=True)

# %%
aqi_NYC_agg = aqi_NYC_agg.groupby('Date').mean()

# %%
plt.figure(figsize=(20, 4))
plt.plot(aqi_NYC_agg)

# %%
aqi_NYC_agg.to_pickle('./datasets/air-quality-reports/aggregates/NYC.pkl')
